# %% [markdown]
# # Bringing it All Together

# %% [markdown]
# #### Here is where we bring all of our data together. We will be displaying the top ten neighborhoods in each of the metrics that we calculated and will decide which neighborhood is the best by choosing the neighborhood that makes the most appearances among all of our metrics.
# -----
# ## Key:
#
# #### If a neighborhood is highlighted <span style ="color:green">green</span> that means it has shown up at least once in one of our top ten metrics
#
# #### If a neighborhood is highlighted <span style ="color:blue">blue</span> that means it has shown up at least twice in one of our top ten metrics
#
# #### If a neighborhood is highlighted <span style ="color:goldenrod">gold</span> that means it has shown up at least three times in one of our top ten metrics
# -----

# %% [markdown]
# ## Employee Count Metric
#
# ### Top 10 neighborhoods with the highest employee count to population percantages:
#
# ##### 1.  <span style ="color:green">Fairywood: 97.8%</span>
#
# ##### 2. <span style ="color:green">North Shore: 94.3%</span>
#
# ##### 3. <span style ="color:green">Friendship: 90.2%</span>
#
# ##### 4. <span style ="color:green">Esplen: 87.7%</span>
#
# ##### 5. <span style ="color:green">Mt. Oliver: 87.3% </span>
#
# ##### 6. <span style ="color:green">Strip District: 87.2% </span>
#
# ##### 7. <span style ="color:green">Central Oakland: 86.4% </span>
#
# ##### 8. <span style ="color:green">Ridgemont: 83.9% </span>
#
# ##### 9. <span style ="color:green">Summer Hill: 83.7% </span>
#
# ##### 10. <span style ="color:green">South Side Flats 82.6%</span>

# %% [markdown]
# -------

# %% [markdown]
# ## Enrollment Count Metric
#
# ### Top 10 neighborhoods with the highest gifted percentage rates:
#
# ##### 1. <span style ="color:green">Squirrel Hill: 32.93%</span>
#
# ##### 2. <span style ="color:green">Squirrel Hill South: 32.22%</span>
#
# ##### 3. <span style ="color:green">Point Breeze: 31.70</span>
#
# ##### 4. <span style ="color:green">Highland Park: 21.73</span>
#
# ##### 5. <span style ="color:green">Greenfield: 18.05</span>
#
# ##### 6. <span style ="color:blue">Bloomfield, Friendship: 14.78</span>
#
# ##### 7. <span style ="color:green">Point Breeze North: 14.73</span>
#
# ##### 8. <span style ="color:blue">South Side Flats: 13.76</span>
#
# ##### 9. <span style ="color:green">Central, Upper Lawrenceville: 13.62</span>
#
# ##### 10. <span style ="color:green">Central Northside: 13.43</span>

# %% [markdown]
# ----

# %% [markdown]
# ## Household Income Metric
#
# ### Top 10 neighborhoods with the highest average household income:
#
# ##### 1.  <span style ="color:green">St. Clair: $176,419</span>
#
# ##### 2. <span style ="color:green">Spring Garden: $171,355</span>
#
# ##### 3. <span style ="color:green">Allegheny West: $162,967</span>
#
# ##### 4. <span style ="color:green">Perry South: $134,482</span>
#
# ##### 5. <span style ="color:green">Polish Hill: $109,850</span>
#
# ##### 6. <span style ="color:green">Central Business District: $106,941</span>
#
# ##### 7. <span style ="color:green">Spring Hill-City View: $91,511</span>
#
# ##### 8. <span style ="color:green">Hazelwood: $81,426</span>
#
# ##### 9. <span style ="color:blue">Ridgemont: $80,924</span>
#
# ##### 10. <span style ="color:green">North Oakland: $80,500</span>

# %% [markdown]
# -----

# %% [markdown]
# ## Neighborhood Parks Metric
#
# ### Top 10 neighborhoods with the most parks:
#
# ##### 1. <span style ="color:green">East Liberty: 12 parks</span>
#
# ##### 2. <span style ="color:blue">Central Business District: 10 parks</span>
#
# ##### 3. <span style ="color:green">Beechview: 8 parks</span>
#
# ##### 4. <span style ="color:green">Point Breeze: 7 parks</span>
#
# ##### 5. <span style ="color:green">South Side Slopes: 7 parks</span>
#
# ##### 6. <span style ="color:blue">Squirrel Hill South: 6 parks</span>
#
# ##### 7. <span style ="color:goldenrod">South Side Flats: 6 parks</span>
#
# ##### 8. <span style ="color:blue">Hazelwood: 6 parks</span>
#
# ##### 9. <span style ="color:green">Sheraden: 6 parks</span>
#
# ##### 10. <span style ="color:green">Mount Washington: 6 parks</span>

# %% [markdown]
# -----

# %% [markdown]
# ----

# %%
from PIL import Image
img = Image.open("Winner.jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=574x360 at 0x7F925411ABB0>

# %% [markdown]
# # &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; South Side Flats!!
